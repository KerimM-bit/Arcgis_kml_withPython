# %%
import geopandas as gpd
import matplotlib.pyplot as plt
#geopandas don't support kml files so we have to add it manually
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'

# %%
data = gpd.read_file("data\Fatih.shp")

mh = ('data\districts.kml')
bina = (r'data\buildings.kml')

poly_mh = gpd.read_file(mh, driver='KML')
poly_mh.head()
# Out:
#           Name Description                                           geometry
# 0      AKSARAY              MULTIPOLYGON (((28.95170 41.00919, 28.95170 41...
# 1  AKŞEMSETTİN              MULTIPOLYGON (((28.94991 41.01730, 28.94947 41...
# 2      ALEMDAR              MULTIPOLYGON (((28.97813 41.01102, 28.97814 41...
# 3    ALİ KUŞÇU              MULTIPOLYGON (((28.95178 41.01717, 28.95118 41...
# 4      ATİKALİ              MULTIPOLYGON (((28.94388 41.02702, 28.94448 41...

# %%
poly_bina = gpd.read_file(bina, driver='KML')
poly_bina.head()
# Out:
#   Name Description                                           geometry
# 0                   MULTIPOLYGON (((28.95936 41.01368, 28.96004 41...
# 1                   MULTIPOLYGON (((28.95872 41.01497, 28.95896 41...
# 2                   MULTIPOLYGON (((28.95861 41.01312, 28.95839 41...
# 3                   MULTIPOLYGON (((28.96296 41.01754, 28.96333 41...
# 4                   MULTIPOLYGON (((28.96181 41.01667, 28.96193 41...

# %%
import pandas as pd

# %%
binalar = poly_bina.copy()

# %%
bina_in_mh = []

for i, poly in poly_mh.iterrows():
    bina_in_this_poly = []
    
    for j, bn in binalar.iterrows():
        if poly.geometry.contains(bn.geometry):
            bina_in_this_poly.append(bn.geometry)
            binalar = binalar.drop([j])
    bina_in_mh.append(len(bina_in_this_poly))
poly_mh['Bina sayi'] = gpd.GeoSeries(bina_in_mh)
# Out:
# C:\Users\User\anaconda3\envs\GIS\lib\site-packages\ipykernel_launcher.py:11: FutureWarning:     You are passing non-geometry data to the GeoSeries constructor. Currently,
#     it falls back to returning a pandas Series. But in the future, we will start
#     to raise a TypeError instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
poly_mh.sort_values(by='Bina sayi', ascending=False)
# Out:
#                   Name Description  \
# 5           AYVANSARAY
# 7                BALAT
# 27     KOCAMUSTAFAPAŞA
# 14           DERVİŞALİ
# 18       HIRKA-İ ŞERİF
# 42           ŞEHREMİNİ
# 54  YAVUZ SULTAN SELİM
# 1          AKŞEMSETTİN
# 44         SEYYİD ÖMER
# 55            YEDİKULE
# 17       HASEKİ SULTAN
# 0              AKSARAY
# 56              ZEYREK
# 22        İSKENDERPAŞA
# 24          KARAGÜMRÜK
# 31         MEVLANAKAPI
# 3            ALİ KUŞÇU
# 12              CİBALİ
# 11          CERRAHPAŞA
# 52             TOPKAPI
# 45         SİLİVRİKAPI
# 35        MOLLA GÜRANİ
# 4              ATİKALİ
# 48       SÜMBÜL EFENDİ
# 25         KATİP KASIM
# 38             NİŞANCA
# 28      KÜÇÜK AYASOFYA
# 10         CANKURTARAN
# 32     MİMAR HAYRETTİN
# 34        MOLLA FENARİ
# 47         SULTANAHMET
# 43        ŞEHSUVAR BEY
# 15          EMİN SİNAN
# 40          SARAÇİSHAK
# 33    MİMAR KEMALETTİN
# 2              ALEMDAR
# 9          BİNBİRDİREK
# 26           KEMALPAŞA
# 30           MESİHPAŞA
# 37       MUHSİNE HATUN
# 21            HOCAPAŞA
# 46         SÜLEYMANİYE
# 29              MERCAN
# 19      HOBYAR EMİNÖNÜ
# 51          TAYA HATUN
# 13            DEMİRTAŞ
# 20     HOCA GIYASETTİN
# 49              SURURİ
# 50           TAHTAKALE
# 36        MOLLA HÜSREV
# 16           HACIKADIN
# 53         YAVUZ SİNAN
# 6           BALABANAĞA
# 23        KALENDERHANE
# 39          RÜSTEMPAŞA
# 8              BEYAZIT
# 41           SARIDEMİR
#
#                                              geometry  Bina sayi
# 5   MULTIPOLYGON (((28.94537 41.03970, 28.94583 41...       1898
# 7   MULTIPOLYGON (((28.94979 41.03272, 28.94982 41...       1535
# 27  MULTIPOLYGON (((28.93687 41.00119, 28.93681 41...       1453
# 14  MULTIPOLYGON (((28.93870 41.03136, 28.93885 41...       1334
# 18  MULTIPOLYGON (((28.93858 41.02523, 28.93858 41...       1327
# 42  MULTIPOLYGON (((28.93312 41.01535, 28.93499 41...       1290
# 54  MULTIPOLYGON (((28.95256 41.03100, 28.95268 41...       1279
# 1   MULTIPOLYGON (((28.94991 41.01730, 28.94947 41...       1096
# 44  MULTIPOLYGON (((28.92684 41.01163, 28.92705 41...       1090
# 55  MULTIPOLYGON (((28.92571 40.99900, 28.92627 40...        937
# 17  MULTIPOLYGON (((28.94857 41.00975, 28.94855 41...        893
# 0   MULTIPOLYGON (((28.95170 41.00919, 28.95170 41...        868
# 56  MULTIPOLYGON (((28.95371 41.02117, 28.95466 41...        858
# 22  MULTIPOLYGON (((28.95118 41.01645, 28.95311 41...        815
# 24  MULTIPOLYGON (((28.93629 41.02948, 28.93676 41...        790
# 31  MULTIPOLYGON (((28.92778 41.01507, 28.92780 41...        785
# 3   MULTIPOLYGON (((28.95178 41.01717, 28.95118 41...        778
# 12  MULTIPOLYGON (((28.95961 41.02630, 28.95969 41...        726
# 11  MULTIPOLYGON (((28.94193 41.00686, 28.94207 41...        681
# 52  MULTIPOLYGON (((28.93388 41.02143, 28.93585 41...        654
# 45  MULTIPOLYGON (((28.93282 41.00682, 28.93276 41...        649
# 35  MULTIPOLYGON (((28.93923 41.01769, 28.94106 41...        640
# 4   MULTIPOLYGON (((28.94388 41.02702, 28.94448 41...        637
# 48  MULTIPOLYGON (((28.92318 41.00352, 28.92328 41...        593
# 25  MULTIPOLYGON (((28.95559 41.00715, 28.95614 41...        551
# 38  MULTIPOLYGON (((28.96231 41.00816, 28.96213 41...        504
# 28  MULTIPOLYGON (((28.97218 41.00516, 28.97236 41...        455
# 10  MULTIPOLYGON (((28.98631 41.01747, 28.98637 41...        453
# 32  MULTIPOLYGON (((28.96897 41.00742, 28.96885 41...        419
# 34  MULTIPOLYGON (((28.97063 41.01159, 28.97076 41...        365
# 47  MULTIPOLYGON (((28.97926 41.00350, 28.97933 41...        357
# 43  MULTIPOLYGON (((28.96796 41.00627, 28.96795 41...        341
# 15  MULTIPOLYGON (((28.97084 41.00719, 28.97083 41...        307
# 40  MULTIPOLYGON (((28.96540 41.00742, 28.96526 41...        297
# 33  MULTIPOLYGON (((28.96402 41.00936, 28.96523 41...        284
# 2   MULTIPOLYGON (((28.97813 41.01102, 28.97814 41...        276
# 9   MULTIPOLYGON (((28.97750 41.00783, 28.97759 41...        266
# 26  MULTIPOLYGON (((28.95731 41.00956, 28.95733 41...        246
# 30  MULTIPOLYGON (((28.95784 41.00830, 28.95788 41...        237
# 37  MULTIPOLYGON (((28.96433 41.00503, 28.96451 41...        235
# 21  MULTIPOLYGON (((28.98536 41.01766, 28.98551 41...        209
# 46  MULTIPOLYGON (((28.96609 41.01656, 28.96612 41...        204
# 29  MULTIPOLYGON (((28.96743 41.01514, 28.96753 41...        191
# 19  MULTIPOLYGON (((28.97680 41.01678, 28.97665 41...        180
# 51  MULTIPOLYGON (((28.97009 41.01392, 28.97013 41...        175
# 13  MULTIPOLYGON (((28.96430 41.01950, 28.96432 41...        160
# 20  MULTIPOLYGON (((28.96376 41.01961, 28.96374 41...        157
# 49  MULTIPOLYGON (((28.97112 41.01463, 28.97125 41...        152
# 50  MULTIPOLYGON (((28.97038 41.01632, 28.97023 41...        150
# 36  MULTIPOLYGON (((28.95894 41.01671, 28.95942 41...        141
# 16  MULTIPOLYGON (((28.96028 41.01705, 28.96025 41...        123
# 53  MULTIPOLYGON (((28.96435 41.01953, 28.96430 41...        118
# 6   MULTIPOLYGON (((28.96112 41.01102, 28.96129 41...        104
# 23  MULTIPOLYGON (((28.96115 41.01119, 28.96112 41...         90
# 39  MULTIPOLYGON (((28.96983 41.01962, 28.96970 41...         72
# 8   MULTIPOLYGON (((28.96814 41.01215, 28.96818 41...         65
# 41  MULTIPOLYGON (((28.96272 41.02291, 28.96276 41...         62

# %%
# We are going to choose distircts with highest number of buildings.
top_3 = poly_mh[poly_mh['Name'].isin(['AYVANSARAY', 'BALAT', 'KOCAMUSTAFAPAŞA'])]
top_3.reset_index(drop=False, inplace=True)

# %%
top_3
# Out:
#    index             Name Description  \
# 0      5       AYVANSARAY
# 1      7            BALAT
# 2     27  KOCAMUSTAFAPAŞA
#
#                                             geometry  Bina sayi
# 0  MULTIPOLYGON (((28.94537 41.03970, 28.94583 41...       1898
# 1  MULTIPOLYGON (((28.94979 41.03272, 28.94982 41...       1535
# 2  MULTIPOLYGON (((28.93687 41.00119, 28.93681 41...       1453

# %%
# %matplotlib inline


#Plotting graph
ax = poly_mh.plot(facecolor='gray');
top_3.plot(ax=ax, facecolor='red');
poly_bina.plot(ax=ax, color='yellow', markersize=5);

plt.tight_layout()

# %%
import shapely.speedups
shapely.speedups.enable()

# %%
top3_mask = poly_mh.within(top_3.loc[0, 'geometry'])
top3_data = poly_mh.loc[top3_mask]

# %%
ax = poly_mh.plot(facecolor='gray', figsize=(20,15))
top_3.plot(ax=ax,facecolor='red', figsize=(20,15))
top3_data.plot(ax=ax, color='gold', markersize=2, figsize=(20,15))
# Out:
# <AxesSubplot:>
